# %%
#DATA STRUCTURE ASSIGNMENT

# %% [markdown]
# 1. What are the data structures and why they are important?
#
#    -data structure are ways to organize and store data efficiently. they are important because they optimize data access ,manipulation,and memory usage,promblem solving ,enable afficient algorithm design.
#
#
# 2. explain the diffrence between mutable and immutble data types with examples?
#
#    -mutables data types can be changed after creation eg;(7,14,21,28,)
#    can be changed as (7,14,28).meanwhile immutable's cannot be changed after creation eg;(tuples(1,2,3)stays fixed cannot be changed)
#
#
# 3. What are the main diffrence between lists and tuples?
#
#    -Lists ([]) are mutable ,ordered and slower whereas;tuples (()) are immutable ,ordered and faster .Tuples use less memory and are used for fix data ,while lists are for dynamic data.
#
#
# 4. describe how dictionaries store data.
#
#    -dictionaries ({}) store data askey value pairs ,using a hash table for O(1) average time lookups,where each key maps to value eg;({"food"="biryani"}).
#
# 5. why might you use a set instead of list in python?
#
#    -Sets ({} or()) set are used for unique elements and fast membership testing (O(1)),unlike lists which allow duplicates and have O(n) lookup time.
#
# 6. what are string in python ,and how is it diffrent from list ?
#
#   -a string ("text") is an immutable sequence of characters.Unlike a lists ,it can't be modified in place and it is designed for text whereas; lists are designed to handel mixed data types.
#
# 7.  how tuples insure data integrity in python?
#
#     - tuples are immutable hence it prevents accidental changes to their elements ,ensuring data consistency and safety in critical application.
#
# 8.  what is hash table ,and how does it relate to dictionaries in python ?
#
#     - a hash table is a data structure using hash functions to store key value pairs for fast retrieval .python dictionaries use has tables internally for O(1) average time access.
#
#
# 9.  can lists contain diffrent data types in python?
#
#     -yes,lists can hold mixed data types (eg;[1,"apple",3,5]), offering flexibility in data storage.
#
# 10.  explain why strings are immutable in python ?
#
#      -strings are immutable to ensure hashability and optimize memory usage by reusing the string .
#
#
# 11.  what advantages do dictionaries offer over lists for certain tasks?
#
#     -dictionaries provide O(1) key based access and are ideal for mapping relationships ,unlike lists which require O(n) index based searches.
#
#
# 12.   Describe a senario where using a tuple would be preferable over a list ?
#
#      -use a tuple for a fixed collection like coordinates (x,y) in a game ,where immutability prevents unintended changes.
#
#
# 13. how do sets handel duplicate values in python ?
#
#     -sets are automically discard duolicates ,keeping only unique elements (eg;{1,2,3} can be modified into {1,2}.
#
#
# 14.  how does the "in"keyword wprk diffrently for lists and dictionaries ?
#
#      - for lists ,in checks if an item exists (O(1)) and returns TRUE if found.
#
# 15. can you modify the elements of a tuple?explain why or why not.
#
#
#    -no,tuples are immutable ,so elements cannot to maintain data integrity and hashability .
#
#
# 16. what is a nested dictionary ,and give an example of its use case?
#
#    -A nested dictionary within a dictionary (eg;{"user":{"name":"nandita","age":18}}).use case : storing hierarchical data like user profiles.
#
# 17. Describe the time complexity of accessing elements in a dictionary .
#
#     - Accessing elements in a dictionary is O(1) on average due to hash table implementation ,though it can be O(n) in rare cases (eg;hash collisions).
#
# 18. in what situations are sets preffered over dictionaries ?
#
#     - Sets are preffered for storing unique ,unordered items (eg;tracking unique IDs ) where key value pairs aren't needed.
#
# 19.  why are dictionaries considered unordered ,and how does that affect data retrieval?
#
#      - dictionaries are unordered (through insertion order is preserved since python 3.7 ) .because theyb rely onhash tables . this allows O(1) retrieval by key not position.
#
#
# 20. explain in the diffrence between a list and a dictionary in terms of data retrieval .
#
#    - lists use integer imdices for O(n) retrieval ,while dictionaries use keys for O(1) average time retrieval ,making dictionaries faster for specific lookups .

# %%
# Write code to create a string with your name and print it .
name="nandita chormare"
print(name)
# Out:
# nandita chormare

# %%
# write a cod eto find length of thestring "hello world".
text="hello world"
print(len(text))
# Out:
# 11

# %%
#write a code to slice the frist three characters from the string python programming
text="python programming"
print(text[0:3])
# Out:
# pyt

# %%
# write a code to convert the string hello to uppercase
text="hello"
print(text.upper())
# Out:
# HELLO

# %%
#write a code to replace the word "apple" with "orange" in the string "i like apple"
text="I like apple"
print(text.replace("apple","orange"))
# Out:
# I like orange

# %%
# write a code to create a list with numbers 1 to 5 and print it.
numbers=[1,2,3,4,5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
#write a code to append the number 10 to the list [1,2,3,4]
numbers=[1,2,3,4]
numbers.append(10)
print(numbers)
# Out:
# [1, 2, 3, 4, 10]

# %%
#write a code to remove number 3 from the list [1,2,3,4,5]
numbers=[1,2,3,4,5]
numbers.remove(3)
print(numbers)
# Out:
# [1, 2, 4, 5]

# %%
#write a code to access second element in the list['a','b','c','d']
letters=['a','b','c','d']
print(letters[1])
# Out:
# b

# %%
#write a code to reverse the list [10,20,30,40,50]
numbers=[10,20,30,40,50]
numbers.reverse()
print(numbers)
# Out:
# [50, 40, 30, 20, 10]

# %%
#write a code to create tuple with the element 100,200,300 and print it.
numbers=(100,200,300)
print(numbers)
# Out:
# (100, 200, 300)

# %%
# write a code to access the second to last element to the tuples (red,green,blue,yellow)
tuple=("red","green","blue","yellow")
print(min(tuple))
# Out:
# blue

# %%
#write a to find minimum number in tuple(10,20,5,15)
numbers=(10,20,5,15)
print(min(numbers))
# Out:
# 5

# %%
#write a code to find a index of the element "cat" in the tuple ('dog','cat','rabbit')
tuple=("dog","cat","rabbit")
print(tuple.index("cat"))
# Out:
# 1

# %%
#write a code to create a set with the elements('a','b','c')and print it
letters={"a","b","c"}
print(letters)
# Out:
# {'a', 'b', 'c'}

# %%
#write a code to create a tuple containing three diffrent fruits and check if 'kiwi'is in it .
fruits=("apple","banana","kiwi","papaya")
print("kiwi"in fruits)
# Out:
# True

# %%
#write a code to clear all the elements from the set{1,2,3,4,5}.
numbers={1,2,3,4,5}
numbers.clear()
print(numbers)
# Out:
# set()

# %%
# write a code to find the intersaction of both sets {1,2,3} and {2,3,4}.
set1={1,2,3}
set2={2,3,4}
print(set1.intersection(set2))
# Out:
# {2, 3}

# %%
#write a code to remove the elements 4 from the set {1,2,3,4}.
numbers={1,2,3,4}
numbers.remove(4)
print(numbers)
# Out:
# {1, 2, 3}

# %%
#write a code to find the union of two sets {1,2,3}and {2,3,4}.
set1={1,2,3}
set2={2,3,4}
print(set1.union(set2))
# Out:
# {1, 2, 3, 4}

# %%
#write a code to create a dictionary with the keys "name","age"and "city" and print it.
info={"name":"nandita","age":18,"city":"nagpur"}
print(info)
# Out:
# {'name': 'nandita', 'age': 18, 'city': 'nagpur'}

# %%
#write a code to add new key values pair"country":"usa"to the dictionary{"name":"john","age","25"}.
info={"name":"john","age":"25"}
info["country"]="usa"
print(info)
# Out:
# {'name': 'john', 'age': '25', 'country': 'usa'}

# %%
#write a code to access the value associated with key "name"in the dictionary{"name":"alice","age":"36"}
dict={"name":"alice","age":"36"}
print(dict['name'])
# Out:
# alice

# %%
#write a code to remove key "age" from the dictionary{"name":"bob","age":"22","city":"newyork"}.
dict={"name":"bob","age":"22","city":"newyork"}
dict.pop("age")
print(dict)
# Out:
# {'name': 'bob', 'city': 'newyork'}

# %%
#write a code to check if the key "city" exists in the dictionary{"name":"alice","city":"paris"}.
dict={"name":"alice","city":"paris"}
if"city" in dict:
  print("city exists in the dict")
# Out:
# city exists in the dict

# %%
#write a code to create a list of 5 random numbers between 1 to 100 ,sort it in acesding order and print it.
import random
numbers=[random.randint(1,100) for i in range (5)]
numbers.sort()
print(numbers)
# Out:
# [13, 37, 60, 80, 90]

# %%
#write a code to create a list with strings and print the element at the third index.
list=['apple','banana','kiwi','cherry']
print(list[2])
# Out:
# kiwi

# %%
#write a code to combine two ditionaries into one and print the result .
list1=['apple','mango','cherry']
list2=['almond','cashew','walnuts']
combined=list1+list2
print(combined)
# Out:
# ['apple', 'mango', 'cherry', 'almond', 'cashew', 'walnuts']

# %%
#write a code to convert a list of strings into set .
list=['apple','banana','kiwi','cherry','banana']
set1=set(list)
print(set1)
# Out:
# {'kiwi', 'cherry', 'apple', 'banana'}
