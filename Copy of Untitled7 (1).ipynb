# %%
###functions

# %%
#what is the difference between function and method in python?
  -"""A function in python is standalone block of code defined with def ,while a method is a function defined inside a class
    eg:function
    def add(5,3):return a+b
    method
    class calc: def add (self,a,b):return a+b"""

# %%
#explain the concept of functions arguments and parameters in python
   -"""Functions arguements are the values passed to function ,while parameters are the variable defined in functions to recieve the value."""
 """  eg:In def greet(name)
   print(name)
   name is the parameter
   whereas,greet("shubham")
   passes shubham is an arguements."""

# %%
#what are the difference ways to define and call a function in python?
   -"""Functions can be defined using def keyword or lambda ,and called by their name with parentheses and arguements.
   eg: def add (a,b):return a+b
   add(5,3)or
   add=lamda a,b:a+b
   add(5,3)"""

# %%
#what is the purpose of the 'return' statement in python function?
  -""" the return statement exits a function and sends a value back to the caller
  eg:def add(a,b):return a+b"""

# %%
#what are iterators in python and how do they differ from interables?
    -"""Interators in python are objects that enable iteration with next (),diferring from iterables (eg:lists) which can be looped over but need an iterator to do so .
    eg:def square(4) return (4**2)"""

# %%
#explain the concept of generations in python and ho wthey are defined?
    _"""Generators are functions that use yield 1;yield 2;
    g=gen()
    next(g)yields 1"""

# %%
#what are the advantages of usings generators over regular functions?
   -"""Advantages of generators include memory efficiency for large data and lazy evaluation.
   eg:def gen_nums():for i in range (1000000):yeild 1
   it uses less memory than regular functions"""

# %%
#what is lamda functions in python and when is it typically used?
"""A lamda functions is a small anonymous functions defined with lamda,typically used for simple operations.
eg:add=lamda 5,3 :5+3"""

# %%
#explain the purpose and the usage of 'map()' functions in python?
_""" The 'map()'function applies a function to all items in an iterable ,returning a map object.
list(maap(lamda* : **2,[1,2,,3,4])) returns[2,4,6,8]"""

# %%
#what is difference between 'map()','reduce()' and 'filter()'functions in python?
""" the map function applies to all the items ,reduce()cumulatively applies for function whereas filter ()selects based on a condition
eg:map(lamda x:x*2 ,[1,2])
reduce (lamda x,y :x+y,[1,2])
filter(lamda x:x%2,[1,2])"""

# %%
#using pen and paper write the internal mechanism for sum operation using reduce function on the given list [47,11,42,13]?
from functools import reduce
number=[47,11,42,13]
result = reduce(lambda x,y:x+y,number)
print("the sum is:",result)
# Out:
# the sum is: 113

# %%
#write a python function that takes a list of numbers asinput and returns the sum of all even number in thelist?
def sum_even(numbers):
    return sum(filter(lambda x:x%2==0,numbers))
numbers=[1,2,3,4,5,6,7,8]
result=sum_even(numbers)
print("the sum of the even number is", result)
# Out:
# the sum of the even number is 20

# %%
#create a function that accepts a string andn returns the reverse of that sstring:
def reverse_string(s):
 return s[::-1]
string="shubham"
print(reverse_string(string))
# Out:
# mahbuhs

# %%
#implement a python function that takes a list of integars and returns new list containing the squares of each no?
def square_list(numbers):
     return [x*x for x in numbers]
numbers=[6,7,8,9]
print(square_list(numbers))
# Out:
# [36, 49, 64, 81]

# %%
#write a python function that checks if given number is prime or not from 1 to 200
def is_prime(n):
  if n < 2:
    return False
  for i in range(2, int(n ** 0.5) + 1):
    if n % i == 0:
      return False
  return True

for num in range(1, 201):
    if is_prime(num):
        print(f"{num} is a prime number")
    else:
        print(f"{num} is not a prime number")
# Out:
# 1 is not a prime number
# 2 is a prime number
# 3 is a prime number
# 4 is not a prime number
# 5 is a prime number
# 6 is not a prime number
# 7 is a prime number
# 8 is not a prime number
# 9 is not a prime number
# 10 is not a prime number
# 11 is a prime number
# 12 is not a prime number
# 13 is a prime number
# 14 is not a prime number
# 15 is not a prime number
# 16 is not a prime number
# 17 is a prime number
# 18 is not a prime number
# 19 is a prime number
# 20 is not a prime number
# 21 is not a prime number
# 22 is not a prime number
# 23 is a prime number
# 24 is not a prime number
# 25 is not a prime number
# 26 is not a prime number
# 27 is not a prime number
# 28 is not a prime number
# 29 is a prime number
# 30 is not a prime number
# 31 is a prime number
# 32 is not a prime number
# 33 is not a prime number
# 34 is not a prime number
# 35 is not a prime number
# 36 is not a prime number
# 37 is a prime number
# 38 is not a prime number
# 39 is not a prime number
# ...

# %%
#create an iterator class in python that generates the fibonacci sequence up to a given number of terms?
class FibonacciIterator:
    def __init__(self, terms):
        self.terms = terms
        self.current_count = 0
        self.a, self.b = 0, 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.current_count >= self.terms:
            raise StopIteration

        if self.current_count == 0:
            self.current_count += 1
            return 0
        elif self.current_count == 1:
            self.current_count += 1
            return 1
        else:
            self.a, self.b = self.b, self.a + self.b
            self.current_count += 1
            return self.b

fib = FibonacciIterator(5)
for num in fib:
    print(num, end=" ")
# Out:
# 0 1 1 2 3

# %%
#write a generator function in python that yeilds the power of 2 up to given exponent?
def power_of_two(exponent):
    for i in range(exponent + 1):
        yield 2 ** i
for power in power_of_two(6):
    print(power, end=" ")
# Out:
# 1 2 4 8 16 32 64

# %%
#use a lamda function in python to sort a list of tuples basedon the second elementof each tuple?
tuples_list =[(1 ,'one'),(3,'three'),(2, 'two')]
sorted_list = sorted(tuples_list, key=lambda x: x[1])
print(sorted_list)
# Out:
# [(1, 'one'), (3, 'three'), (2, 'two')]

# %%
#write a python program that uses 'map()'to convert a list of tempratures from celsius to fahhrenheit?
celsius =[0, 37,100]
fahrenheit = list(map(lambda x:(x * 9/5) + 32, celsius))
print(fahrenheit)
# Out:
# [32.0, 98.6, 212.0]

# %%
#create a python program that uses 'filter ()' to remove all the vowels from a given string.
def remove_vowels(string):
    vowels = 'aeiouAEIOU'
    return ''.join(filter(lambda x: x not in vowels, string))
    string = "shubham"
    print(remove_vowels("shubham"))

# %%
# accounting routine with 2-tuples using lambda and map()
order = [
    [34587, 4, 40],
    [98762, 18, 120],
    [77226, 2, 50],
    [88112, 3,24]
]

result= list(map(lambda x : x[1] * x[2] * (1.10 if x[1] * x[2] < 100 else 1), order))
print(result)
# Out:
# [160, 2160, 100, 79.2]
